# %% [markdown]
# # CNN-LSTM Model

# %% [markdown]
# The following notebook is a guide into using a hybrid model, that is when two models are trained together in order to increase \
# the accuracy of the predicition. In this case, to detect someones sitting posture (3 classifications: leaning left, leaning right, sitting straight), \
# we are using a Convolutional Neural Network (CNN) to grab the spatial features of the images and a Long Short Term Memory (LSTM) model to grab \
# the temporal features of the images that are organized in sequence to better study the movement of the subject.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import tensorflow as tf
import cv2

# %% [markdown]
# ## Resizing & Dataset Preparation

# %% [markdown]
# Resizing is not necessary but it makes the trainin quicker. For this use case, more pixels does not necessary help. \
# The rest of the code takes care of preparing all the classified images so that they are \
# in order of time e.g. a person moving frame by frame to the right. This is needed for the LSTM model.

# %% [markdown]
# Function to Resize the image from (720,1280,3) to (180,320,3)

# %%
def get_img(img_path):
    original_img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    resized_img = cv2.resize(original_img, (320,180), interpolation=cv2.INTER_CUBIC)
    return resized_img

# %% [markdown]
# **To Concatanate 8 Images in a sample for our TimeDistributed Layer**

# %%
prefix = "frames/train/left/1/"          ## change to your own folder path

X_sample = []
for idx in range(1, 9):
    img_path = prefix + str(idx) + ".jpg"
    img = get_img(img_path)
    X_sample.append(img)

print (np.array(X_sample).shape)
# Out:
# (8, 180, 320, 3)

# %% [markdown]
# **To Convert the Training data into Required format to feed the data into model.**

# %%
main_prefix="frames-full-9/train/"   ## change to your own folder path
x_left=[]
x_right=[]
x_straight=[]

for i in range(1,9):
    path=main_prefix+'/left/'+str(i)+"/"
    X_sample = []
    for idx in range(1, 10):
        img_path = path + str(idx) + ".jpg"
        img = get_img(img_path)
        X_sample.append(img)
    x_left.append(np.array(X_sample))
        
for i in range(1,9):
    path=main_prefix+'/right/'+str(i)+"/"
    X_sample = []
    for idx in range(1, 10):
        img_path = path + str(idx) + ".jpg"
        img = get_img(img_path)
        X_sample.append(img)
    x_right.append(np.array(X_sample))
        
for i in range(1,9):
    path=main_prefix+'straight/'+str(i)+"/"
    X_sample = []
    for idx in range(1, 10):
        img_path = path + str(idx) + ".jpg"
        img = get_img(img_path)
        X_sample.append(img)
    x_straight.append(np.array(X_sample))

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

y_train = ['left'] * 90 + ['right'] * 90 + ['straight'] * 90
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
num_classes = len(label_encoder.classes_)
y_train_onehot = keras.utils.to_categorical(y_train_encoded, num_classes)

# %%
print(np.array(x_left).shape)
print(np.array(x_right).shape)
print(np.array(x_straight).shape)
# Out:
# (8, 9, 180, 320, 3)
# (8, 9, 180, 320, 3)
# (8, 9, 180, 320, 3)

# %% [markdown]
# ## Model Layer Configuration

# %% [markdown]
# In the following code the data is inputted in the CNN model first, then flattened such as is output is the input of the LSTM layer.\
# In between this process is a TimeDistributed Layer so that the LSTM model can read each video frame (an image) in sequence and \
# understand the temporal differences of movement.

# %%
from tensorflow import keras
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, TimeDistributed, LSTM

model=None

cnn = Sequential()

cnn.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(180,320,3)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.75))
cnn.add(Conv2D(32, (3,3), 1, activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.75))
cnn.add(Conv2D(64, (3,3), 1, activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.5))
cnn.add(Flatten())

model = Sequential()

model.add(TimeDistributed(cnn, input_shape=(10, 180, 320, 3)))                          ###Using TimeDistributed Layer to Feed the Image Sequence

# now, flatten  each output to send 8 outputs with one dimension to LSTM
model.add( TimeDistributed( Flatten()  ))
model.add(LSTM(256, activation='relu', return_sequences=False))                                   ##Added LSTM to Capture the Sequence Information
# finalize with standard Dense, Dropout...
model.add(Dense(64, activation='relu'))                                           ##Final Adding an Dense Layer
model.add(Dropout(.5))    

optimizer = tf.keras.optimizers.legacy.Adam(0.00001)
optimizer.learning_rate.assign(0.00001)
model.add(Dense(3))                                         
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_171"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_169 (Time  (None, 10, 2592)          18960
#  Distributed)
#
#  time_distributed_170 (Time  (None, 10, 2592)          0
#  Distributed)
#
#  lstm_31 (LSTM)              (None, 256)               2917376
#
#  dense_167 (Dense)           (None, 64)                16448
#
#  dropout_342 (Dropout)       (None, 64)                0
#
#  dense_168 (Dense)           (None, 3)                 195
#
# =================================================================
# Total params: 2952979 (11.26 MB)
# Trainable params: 2952979 (11.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
## standard training

x_train = np.concatenate((x_left, x_right, x_straight))

r=model.fit(x_train ,y_train_onehot,validation_split=0.2,batch_size=10,epochs=50, shuffle=True)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 721ms/step - loss: 0.6444 - accuracy: 0.5789 - val_loss: 0.4851 - val_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 1s 610ms/step - loss: 6.2953 - accuracy: 0.4211 - val_loss: 0.5258 - val_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 1s 587ms/step - loss: 3.5866 - accuracy: 0.7895 - val_loss: 0.5350 - val_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 1s 583ms/step - loss: 2.7834 - accuracy: 0.7895 - val_loss: 0.5275 - val_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 1s 561ms/step - loss: 5.3868 - accuracy: 0.6842 - val_loss: 0.5131 - val_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 1s 558ms/step - loss: 2.1608 - accuracy: 0.4737 - val_loss: 0.5150 - val_accuracy: 0.8000
# Epoch 7/50
# 2/2 [==============================] - 1s 556ms/step - loss: 2.1668 - accuracy: 0.6842 - val_loss: 0.4887 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 1s 552ms/step - loss: 1.8530 - accuracy: 0.8421 - val_loss: 0.4653 - val_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 1s 554ms/step - loss: 4.5905 - accuracy: 0.6316 - val_loss: 0.4454 - val_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 1s 555ms/step - loss: 4.6434 - accuracy: 0.5789 - val_loss: 0.4417 - val_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 1s 560ms/step - loss: 3.7248 - accuracy: 0.7895 - val_loss: 0.4282 - val_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 1s 554ms/step - loss: 4.4711 - accuracy: 0.7895 - val_loss: 0.4193 - val_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 1s 558ms/step - loss: 5.4757 - accuracy: 0.6842 - val_loss: 0.4139 - val_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 1s 559ms/step - loss: 4.5485 - accuracy: 0.7368 - val_loss: 0.4150 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 1s 560ms/step - loss: 4.6935 - accuracy: 0.7368 - val_loss: 0.4191 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 1s 561ms/step - loss: 3.6953 - accuracy: 0.5789 - val_loss: 0.4233 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 1s 561ms/step - loss: 6.4232 - accuracy: 0.6316 - val_loss: 0.4257 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 1s 559ms/step - loss: 5.2135 - accuracy: 0.7895 - val_loss: 0.4261 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 1s 560ms/step - loss: 2.9666 - accuracy: 0.5789 - val_loss: 0.4255 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 1s 553ms/step - loss: 2.2311 - accuracy: 0.5789 - val_loss: 0.4194 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 1s 557ms/step - loss: 2.8927 - accuracy: 0.5789 - val_loss: 0.4104 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 1s 556ms/step - loss: 5.5629 - accuracy: 0.7895 - val_loss: 0.4100 - val_accuracy: 0.8000
# Epoch 23/50
# 2/2 [==============================] - 1s 557ms/step - loss: 2.4048 - accuracy: 0.6316 - val_loss: 0.4064 - val_accuracy: 0.8000
# Epoch 24/50
# 2/2 [==============================] - 1s 564ms/step - loss: 3.0208 - accuracy: 0.6316 - val_loss: 0.3900 - val_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 1s 551ms/step - loss: 1.6326 - accuracy: 0.7368 - val_loss: 0.3438 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 1s 563ms/step - loss: 3.5592 - accuracy: 0.7368 - val_loss: 0.4111 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 1s 560ms/step - loss: 3.0081 - accuracy: 0.7368 - val_loss: 0.3479 - val_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 1s 557ms/step - loss: 2.7285 - accuracy: 0.6316 - val_loss: 0.3299 - val_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 1s 561ms/step - loss: 4.6850 - accuracy: 0.6842 - val_loss: 0.3524 - val_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 1s 559ms/step - loss: 3.6683 - accuracy: 0.7368 - val_loss: 0.2797 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 1s 564ms/step - loss: 2.9076 - accuracy: 0.5789 - val_loss: 0.2666 - val_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 1s 565ms/step - loss: 4.5403 - accuracy: 0.6842 - val_loss: 0.2581 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 1s 572ms/step - loss: 2.2451 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 1s 568ms/step - loss: 6.1763 - accuracy: 0.6842 - val_loss: 0.2498 - val_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 1s 569ms/step - loss: 1.8343 - accuracy: 0.8421 - val_loss: 0.2475 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 1s 569ms/step - loss: 3.8426 - accuracy: 0.7368 - val_loss: 0.2461 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 1s 563ms/step - loss: 4.4854 - accuracy: 0.7895 - val_loss: 0.2468 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 1s 560ms/step - loss: 2.9915 - accuracy: 0.7368 - val_loss: 0.2474 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 1s 565ms/step - loss: 4.1214 - accuracy: 0.5789 - val_loss: 0.2531 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 1s 567ms/step - loss: 4.6307 - accuracy: 0.7368 - val_loss: 0.2585 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 1s 566ms/step - loss: 5.3632 - accuracy: 0.6842 - val_loss: 0.3392 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 1s 566ms/step - loss: 4.8169 - accuracy: 0.7895 - val_loss: 0.3632 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 1s 569ms/step - loss: 4.5833 - accuracy: 0.7368 - val_loss: 0.3581 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 1s 596ms/step - loss: 5.4097 - accuracy: 0.6316 - val_loss: 0.3431 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 1s 568ms/step - loss: 4.0199 - accuracy: 0.7895 - val_loss: 0.3200 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 1s 569ms/step - loss: 4.8928 - accuracy: 0.4737 - val_loss: 0.3023 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 1s 565ms/step - loss: 4.6647 - accuracy: 0.7368 - val_loss: 0.2932 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 1s 565ms/step - loss: 3.5801 - accuracy: 0.7368 - val_loss: 0.3014 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 1s 568ms/step - loss: 4.5657 - accuracy: 0.5789 - val_loss: 0.3109 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 1s 564ms/step - loss: 3.6703 - accuracy: 0.7895 - val_loss: 0.3384 - val_accuracy: 1.0000

# %% [markdown]
# ## Visualizations

# %% [markdown]
# Visualizing the loss

# %%
fig = plt.figure()
plt.plot(r.history['loss'], color='teal', label='loss')
plt.plot(r.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Visualizing the model accuracy

# %%
fig = plt.figure()
plt.plot(r.history['accuracy'], color='teal', label='accuracy')
plt.plot(r.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## K-fold Testing

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed, LSTM, Dense, Dropout, Flatten, GRU
from tensorflow.keras.utils import to_categorical


dataset_path = "path/to/testing/folder"

def load_sequence(folder_path):
    image_list = os.listdir(folder_path)
    image_list.sort()  # Sort images in ascending order

    # Load and preprocess the images
    images = []
    for image_name in image_list:
        image_path = os.path.join(folder_path, image_name)
        if ".DS_Store" not in image_path:
            image = load_img(image_path, target_size=(180, 320))
            image = img_to_array(image)
            images.append(image)

    # Stack the images to create a sequence
    sequence = np.stack(images, axis=0)
    return sequence

class_folders = os.listdir(dataset_path)

sequences = []
labels = []

# Iterate over each class folder
for class_folder in class_folders:
    class_path = os.path.join(dataset_path, class_folder)

    # Iterate over each sequence folder
    if ".DS_Store" not in class_path:
        sequence_folders = os.listdir(class_path)

        for sequence_folder in sequence_folders:
            if ".DS_Store" not in sequence_folder:
                sequence_path = os.path.join(class_path, sequence_folder)

                # Load the sequence
                sequence = load_sequence(sequence_path)
                sequences.append(sequence)
                labels.append(class_folder)

# Pad or truncate the sequences to have a length of x
sequences = pad_sequences(sequences, maxlen=10, padding='post', truncating='post')

sequences = tf.convert_to_tensor(sequences)

# Convert labels to integer format
label_encoder = LabelEncoder()
integer_labels = label_encoder.fit_transform(labels)
labels = tf.convert_to_tensor(integer_labels)

k = 5
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

fold_scores = []

for train_indices, val_indices in kfold.split(sequences):
    train_indices = tf.constant(train_indices, dtype=tf.int64)
    val_indices = tf.constant(val_indices, dtype=tf.int64)

    train_sequences = tf.gather(sequences, train_indices)
    train_labels = tf.gather(labels, train_indices)
    val_sequences = tf.gather(sequences, val_indices)
    val_labels = tf.gather(labels, val_indices)
    
    one_hot_labels = to_categorical(train_labels)
    train_labels = tf.convert_to_tensor(one_hot_labels)
    
    one_hot_labels_val = to_categorical(val_labels)
    val_labels = tf.convert_to_tensor(one_hot_labels_val)

    cnn = Sequential()

    cnn.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(180,320,3)))
    cnn.add(MaxPooling2D())
    cnn.add(Dropout(0.75))
    cnn.add(Conv2D(32, (3,3), 1, activation='relu'))
    cnn.add(MaxPooling2D())
    cnn.add(Dropout(0.75))
    cnn.add(Conv2D(64, (3,3), 1, activation='relu'))
    cnn.add(MaxPooling2D())
    cnn.add(Dropout(0.5))
    cnn.add(Flatten())

    model = Sequential()

    model.add(TimeDistributed(cnn, input_shape=(10, 180, 320, 3)))                         
    model.add(TimeDistributed( Flatten()))
    model.add(LSTM(256, activation='relu', return_sequences=False))                                 
    # model.add(GRU(64, activation='relu', return_sequences=False))                                 
    model.add(Dense(64, activation='relu'))                                         
    model.add(Dropout(.5))    

    optimizer = tf.keras.optimizers.legacy.Adam(0.001)
    optimizer.learning_rate.assign(0.001)

    model.add(Dense(3, activation='softmax'))                                      
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(train_sequences, train_labels, epochs=50)
    _, model_eval = model.evaluate(val_sequences, val_labels)
    fold_scores.append(model_eval)
    print(model_eval)

print(np.mean(fold_scores))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 5s 528ms/step - loss: 181.6581 - accuracy: 0.4250
# Epoch 2/50
# 2/2 [==============================] - 3s 547ms/step - loss: 665.8298 - accuracy: 0.4000
# Epoch 3/50
# 2/2 [==============================] - 3s 486ms/step - loss: 621.3412 - accuracy: 0.4250
# Epoch 4/50
# 2/2 [==============================] - 3s 512ms/step - loss: 253.0385 - accuracy: 0.6500
# Epoch 5/50
# 2/2 [==============================] - 3s 480ms/step - loss: 161.8580 - accuracy: 0.7500
# Epoch 6/50
# 2/2 [==============================] - 3s 487ms/step - loss: 309.6888 - accuracy: 0.5750
# Epoch 7/50
# 2/2 [==============================] - 3s 498ms/step - loss: 143.4039 - accuracy: 0.6750
# Epoch 8/50
# 2/2 [==============================] - 3s 498ms/step - loss: 235.0974 - accuracy: 0.7000
# Epoch 9/50
# 2/2 [==============================] - 3s 483ms/step - loss: 106.5674 - accuracy: 0.7000
# Epoch 10/50
# 2/2 [==============================] - 3s 499ms/step - loss: 141.2497 - accuracy: 0.7500
# Epoch 11/50
# 2/2 [==============================] - 3s 525ms/step - loss: 157.2251 - accuracy: 0.7000
# Epoch 12/50
# 2/2 [==============================] - 3s 489ms/step - loss: 46.7334 - accuracy: 0.7750
# Epoch 13/50
# 2/2 [==============================] - 3s 482ms/step - loss: 107.2845 - accuracy: 0.7250
# Epoch 14/50
# 2/2 [==============================] - 3s 474ms/step - loss: 91.0307 - accuracy: 0.6750
# Epoch 15/50
# 2/2 [==============================] - 3s 484ms/step - loss: 82.0327 - accuracy: 0.7750
# Epoch 16/50
# 2/2 [==============================] - 3s 519ms/step - loss: 25.9884 - accuracy: 0.8000
# Epoch 17/50
# 2/2 [==============================] - 3s 552ms/step - loss: 38.0968 - accuracy: 0.8000
# Epoch 18/50
# 2/2 [==============================] - 3s 498ms/step - loss: 33.1268 - accuracy: 0.8250
# Epoch 19/50
# 2/2 [==============================] - 3s 511ms/step - loss: 45.2305 - accuracy: 0.7750
# Epoch 20/50
# 2/2 [==============================] - 3s 541ms/step - loss: 33.2321 - accuracy: 0.8750
# Epoch 21/50
# 2/2 [==============================] - 3s 485ms/step - loss: 23.3850 - accuracy: 0.8250
# Epoch 22/50
# 2/2 [==============================] - 3s 559ms/step - loss: 33.8201 - accuracy: 0.8750
# Epoch 23/50
# 2/2 [==============================] - 3s 478ms/step - loss: 5.9002 - accuracy: 0.9250
# Epoch 24/50
# 2/2 [==============================] - 3s 485ms/step - loss: 17.7483 - accuracy: 0.9000
# Epoch 25/50
# 2/2 [==============================] - 3s 489ms/step - loss: 8.6218 - accuracy: 0.9000
# Epoch 26/50
# 2/2 [==============================] - 3s 494ms/step - loss: 20.5287 - accuracy: 0.9250
# Epoch 27/50
# 2/2 [==============================] - 3s 488ms/step - loss: 37.2131 - accuracy: 0.7750
# Epoch 28/50
# 2/2 [==============================] - 3s 495ms/step - loss: 6.5218 - accuracy: 0.9250
# Epoch 29/50
# 2/2 [==============================] - 3s 502ms/step - loss: 22.1034 - accuracy: 0.9000
# Epoch 30/50
# 2/2 [==============================] - 3s 498ms/step - loss: 9.3430 - accuracy: 0.9000
# Epoch 31/50
# 2/2 [==============================] - 3s 529ms/step - loss: 27.9684 - accuracy: 0.9000
# Epoch 32/50
# 2/2 [==============================] - 3s 504ms/step - loss: 11.8023 - accuracy: 0.8750
# Epoch 33/50
# 2/2 [==============================] - 3s 510ms/step - loss: 13.1201 - accuracy: 0.8750
# Epoch 34/50
# 2/2 [==============================] - 3s 497ms/step - loss: 0.0662 - accuracy: 0.9750
# Epoch 35/50
# 2/2 [==============================] - 3s 490ms/step - loss: 16.5718 - accuracy: 0.9250
# Epoch 36/50
# 2/2 [==============================] - 3s 498ms/step - loss: 15.7000 - accuracy: 0.9000
# Epoch 37/50
# 2/2 [==============================] - 3s 495ms/step - loss: 10.3830 - accuracy: 0.8750
# Epoch 38/50
# 2/2 [==============================] - 3s 509ms/step - loss: 2.9490 - accuracy: 0.9000
# Epoch 39/50
# 2/2 [==============================] - 3s 519ms/step - loss: 9.5600 - accuracy: 0.9250
# Epoch 40/50
# 2/2 [==============================] - 3s 508ms/step - loss: 18.6617 - accuracy: 0.9500
# Epoch 41/50
# 2/2 [==============================] - 3s 499ms/step - loss: 23.9985 - accuracy: 0.9250
# Epoch 42/50
# 2/2 [==============================] - 3s 487ms/step - loss: 19.8077 - accuracy: 0.9250
# Epoch 43/50
# 2/2 [==============================] - 3s 484ms/step - loss: 6.7709 - accuracy: 0.9000
# Epoch 44/50
# 2/2 [==============================] - 3s 505ms/step - loss: 7.1576 - accuracy: 0.9000
# Epoch 45/50
# 2/2 [==============================] - 3s 497ms/step - loss: 12.7776 - accuracy: 0.9000
# Epoch 46/50
# 2/2 [==============================] - 3s 506ms/step - loss: 10.5546 - accuracy: 0.9000
# Epoch 47/50
# 2/2 [==============================] - 3s 476ms/step - loss: 5.0263 - accuracy: 0.9250
# Epoch 48/50
# 2/2 [==============================] - 3s 489ms/step - loss: 4.9480 - accuracy: 0.9250
# Epoch 49/50
# 2/2 [==============================] - 3s 483ms/step - loss: 2.7156 - accuracy: 0.9250
# Epoch 50/50
# 2/2 [==============================] - 3s 494ms/step - loss: 2.5958 - accuracy: 0.9250
# 1/1 [==============================] - 0s 323ms/step - loss: 0.2673 - accuracy: 0.9091
# 0.9090909361839294
# Epoch 1/50
# 2/2 [==============================] - 4s 579ms/step - loss: 164.2915 - accuracy: 0.3902
# Epoch 2/50
# 2/2 [==============================] - 3s 596ms/step - loss: 244.2021 - accuracy: 0.5366
# Epoch 3/50
# 2/2 [==============================] - 3s 572ms/step - loss: 301.7875 - accuracy: 0.5122
# Epoch 4/50
# 2/2 [==============================] - 3s 593ms/step - loss: 184.1213 - accuracy: 0.6098
# Epoch 5/50
# 2/2 [==============================] - 3s 606ms/step - loss: 227.7456 - accuracy: 0.5610
# Epoch 6/50
# 2/2 [==============================] - 3s 563ms/step - loss: 160.1025 - accuracy: 0.6098
# Epoch 7/50
# 2/2 [==============================] - 3s 558ms/step - loss: 165.6804 - accuracy: 0.6829
# Epoch 8/50
# 2/2 [==============================] - 3s 572ms/step - loss: 170.3056 - accuracy: 0.7317
# Epoch 9/50
# 2/2 [==============================] - 3s 569ms/step - loss: 89.4056 - accuracy: 0.7317
# Epoch 10/50
# 2/2 [==============================] - 3s 563ms/step - loss: 144.7417 - accuracy: 0.6341
# Epoch 11/50
# 2/2 [==============================] - 3s 618ms/step - loss: 93.3674 - accuracy: 0.7317
# Epoch 12/50
# 2/2 [==============================] - 3s 560ms/step - loss: 57.1691 - accuracy: 0.8293
# Epoch 13/50
# 2/2 [==============================] - 3s 561ms/step - loss: 47.2449 - accuracy: 0.7317
# Epoch 14/50
# 2/2 [==============================] - 3s 550ms/step - loss: 25.3958 - accuracy: 0.8293
# Epoch 15/50
# 2/2 [==============================] - 3s 571ms/step - loss: 33.0564 - accuracy: 0.7317
# Epoch 16/50
# 2/2 [==============================] - 3s 572ms/step - loss: 25.1368 - accuracy: 0.8293
# Epoch 17/50
# 2/2 [==============================] - 3s 557ms/step - loss: 16.8560 - accuracy: 0.8293
# Epoch 18/50
# 2/2 [==============================] - 3s 582ms/step - loss: 9.1652 - accuracy: 0.8780
# Epoch 19/50
# 2/2 [==============================] - 3s 565ms/step - loss: 6.1798 - accuracy: 0.8780
# Epoch 20/50
# 2/2 [==============================] - 3s 571ms/step - loss: 11.1357 - accuracy: 0.7805
# Epoch 21/50
# 2/2 [==============================] - 3s 588ms/step - loss: 7.3306 - accuracy: 0.9024
# Epoch 22/50
# 2/2 [==============================] - 3s 627ms/step - loss: 4.6688 - accuracy: 0.9268
# Epoch 23/50
# 2/2 [==============================] - 3s 632ms/step - loss: 7.6396 - accuracy: 0.8293
# Epoch 24/50
# 2/2 [==============================] - 3s 602ms/step - loss: 6.5292 - accuracy: 0.8780
# Epoch 25/50
# 2/2 [==============================] - 3s 554ms/step - loss: 3.9620 - accuracy: 0.8537
# Epoch 26/50
# 2/2 [==============================] - 3s 556ms/step - loss: 1.0210 - accuracy: 0.9024
# Epoch 27/50
# 2/2 [==============================] - 3s 559ms/step - loss: 1.0891 - accuracy: 0.9268
# Epoch 28/50
# 2/2 [==============================] - 3s 589ms/step - loss: 1.4752 - accuracy: 0.9268
# Epoch 29/50
# 2/2 [==============================] - 3s 580ms/step - loss: 0.5301 - accuracy: 0.9024
# Epoch 30/50
# 2/2 [==============================] - 3s 580ms/step - loss: 2.1287 - accuracy: 0.9024
# Epoch 31/50
# 2/2 [==============================] - 3s 601ms/step - loss: 5.7515 - accuracy: 0.7805
# Epoch 32/50
# 2/2 [==============================] - 3s 565ms/step - loss: 1.1485 - accuracy: 0.9024
# Epoch 33/50
# 2/2 [==============================] - 3s 576ms/step - loss: 17.9064 - accuracy: 0.8293
# Epoch 34/50
# 2/2 [==============================] - 3s 574ms/step - loss: 35.7571 - accuracy: 0.8293
# Epoch 35/50
# 2/2 [==============================] - 3s 561ms/step - loss: 9.7682 - accuracy: 0.7561
# Epoch 36/50
# 2/2 [==============================] - 3s 591ms/step - loss: 4.1275 - accuracy: 0.8049
# Epoch 37/50
# 2/2 [==============================] - 3s 599ms/step - loss: 16.3609 - accuracy: 0.8537
# Epoch 38/50
# 2/2 [==============================] - 3s 571ms/step - loss: 1.0276 - accuracy: 0.9268
# Epoch 39/50
# 2/2 [==============================] - 3s 550ms/step - loss: 12.7397 - accuracy: 0.8780
# Epoch 40/50
# 2/2 [==============================] - 3s 562ms/step - loss: 6.0065 - accuracy: 0.9024
# Epoch 41/50
# 2/2 [==============================] - 3s 555ms/step - loss: 4.6618 - accuracy: 0.8780
# Epoch 42/50
# 2/2 [==============================] - 3s 566ms/step - loss: 9.9903 - accuracy: 0.9024
# Epoch 43/50
# 2/2 [==============================] - 3s 564ms/step - loss: 1.9524 - accuracy: 0.9268
# Epoch 44/50
# 2/2 [==============================] - 3s 594ms/step - loss: 0.6878 - accuracy: 0.9512
# Epoch 45/50
# 2/2 [==============================] - 3s 570ms/step - loss: 2.0456 - accuracy: 0.9024
# Epoch 46/50
# 2/2 [==============================] - 3s 555ms/step - loss: 1.1071 - accuracy: 0.9268
# Epoch 47/50
# 2/2 [==============================] - 3s 564ms/step - loss: 3.0660 - accuracy: 0.9268
# Epoch 48/50
# 2/2 [==============================] - 3s 556ms/step - loss: 4.4885 - accuracy: 0.8780
# Epoch 49/50
# 2/2 [==============================] - 3s 566ms/step - loss: 5.0607 - accuracy: 0.9024
# Epoch 50/50
# 2/2 [==============================] - 3s 555ms/step - loss: 0.5435 - accuracy: 0.9268
# 1/1 [==============================] - 0s 288ms/step - loss: 0.6153 - accuracy: 0.8000
# 0.800000011920929
# Epoch 1/50
# 2/2 [==============================] - 4s 586ms/step - loss: 170.2416 - accuracy: 0.3659
# Epoch 2/50
# 2/2 [==============================] - 3s 568ms/step - loss: 319.9835 - accuracy: 0.3902
# Epoch 3/50
# 2/2 [==============================] - 3s 586ms/step - loss: 289.4789 - accuracy: 0.6098
# Epoch 4/50
# 2/2 [==============================] - 3s 622ms/step - loss: 281.5079 - accuracy: 0.5610
# Epoch 5/50
# 2/2 [==============================] - 3s 552ms/step - loss: 214.0096 - accuracy: 0.5854
# Epoch 6/50
# 2/2 [==============================] - 3s 588ms/step - loss: 110.1795 - accuracy: 0.7805
# Epoch 7/50
# 2/2 [==============================] - 3s 558ms/step - loss: 136.0722 - accuracy: 0.5854
# Epoch 8/50
# 2/2 [==============================] - 3s 541ms/step - loss: 102.8077 - accuracy: 0.6585
# Epoch 9/50
# 2/2 [==============================] - 3s 535ms/step - loss: 101.6531 - accuracy: 0.6341
# Epoch 10/50
# 2/2 [==============================] - 3s 541ms/step - loss: 65.3484 - accuracy: 0.7073
# Epoch 11/50
# 2/2 [==============================] - 3s 540ms/step - loss: 90.1151 - accuracy: 0.6341
# Epoch 12/50
# 2/2 [==============================] - 3s 554ms/step - loss: 23.9536 - accuracy: 0.8049
# Epoch 13/50
# 2/2 [==============================] - 3s 556ms/step - loss: 29.8319 - accuracy: 0.8049
# Epoch 14/50
# 2/2 [==============================] - 3s 581ms/step - loss: 26.4630 - accuracy: 0.7805
# Epoch 15/50
# 2/2 [==============================] - 3s 557ms/step - loss: 18.6207 - accuracy: 0.7805
# Epoch 16/50
# 2/2 [==============================] - 3s 547ms/step - loss: 14.4843 - accuracy: 0.7561
# Epoch 17/50
# 2/2 [==============================] - 3s 542ms/step - loss: 12.0995 - accuracy: 0.8293
# Epoch 18/50
# 2/2 [==============================] - 3s 534ms/step - loss: 13.5919 - accuracy: 0.7805
# Epoch 19/50
# 2/2 [==============================] - 3s 571ms/step - loss: 4.9032 - accuracy: 0.8780
# Epoch 20/50
# 2/2 [==============================] - 3s 551ms/step - loss: 9.9468 - accuracy: 0.8537
# Epoch 21/50
# 2/2 [==============================] - 3s 544ms/step - loss: 23.9895 - accuracy: 0.7317
# Epoch 22/50
# 2/2 [==============================] - 3s 536ms/step - loss: 8.3189 - accuracy: 0.8780
# Epoch 23/50
# 2/2 [==============================] - 3s 549ms/step - loss: 2.6387 - accuracy: 0.9024
# Epoch 24/50
# 2/2 [==============================] - 3s 553ms/step - loss: 5.2198 - accuracy: 0.8049
# Epoch 25/50
# 2/2 [==============================] - 3s 545ms/step - loss: 2.1328 - accuracy: 0.8780
# Epoch 26/50
# 2/2 [==============================] - 3s 535ms/step - loss: 3.9743 - accuracy: 0.8780
# Epoch 27/50
# 2/2 [==============================] - 3s 534ms/step - loss: 2.5635 - accuracy: 0.9268
# Epoch 28/50
# 2/2 [==============================] - 3s 536ms/step - loss: 6.2837 - accuracy: 0.8049
# Epoch 29/50
# 2/2 [==============================] - 3s 538ms/step - loss: 3.3064 - accuracy: 0.9024
# Epoch 30/50
# 2/2 [==============================] - 3s 536ms/step - loss: 1.1389 - accuracy: 0.9512
# Epoch 31/50
# 2/2 [==============================] - 3s 543ms/step - loss: 5.5539 - accuracy: 0.8537
# Epoch 32/50
# 2/2 [==============================] - 3s 561ms/step - loss: 5.8428 - accuracy: 0.7805
# Epoch 33/50
# 2/2 [==============================] - 3s 548ms/step - loss: 3.6320 - accuracy: 0.8537
# Epoch 34/50
# 2/2 [==============================] - 3s 554ms/step - loss: 2.9743 - accuracy: 0.8780
# Epoch 35/50
# 2/2 [==============================] - 3s 538ms/step - loss: 1.6421 - accuracy: 0.9024
# Epoch 36/50
# 2/2 [==============================] - 3s 535ms/step - loss: 2.6699 - accuracy: 0.9024
# Epoch 37/50
# 2/2 [==============================] - 3s 544ms/step - loss: 3.2333 - accuracy: 0.8537
# Epoch 38/50
# 2/2 [==============================] - 3s 523ms/step - loss: 4.6065 - accuracy: 0.8780
# Epoch 39/50
# 2/2 [==============================] - 3s 541ms/step - loss: 1.6694 - accuracy: 0.8780
# Epoch 40/50
# 2/2 [==============================] - 3s 549ms/step - loss: 4.5772 - accuracy: 0.8293
# Epoch 41/50
# 2/2 [==============================] - 3s 537ms/step - loss: 1.6035 - accuracy: 0.9024
# Epoch 42/50
# 2/2 [==============================] - 3s 533ms/step - loss: 0.5152 - accuracy: 0.9512
# Epoch 43/50
# 2/2 [==============================] - 3s 582ms/step - loss: 0.9990 - accuracy: 0.8780
# Epoch 44/50
# 2/2 [==============================] - 3s 564ms/step - loss: 3.8844 - accuracy: 0.8293
# Epoch 45/50
# 2/2 [==============================] - 3s 542ms/step - loss: 2.2654 - accuracy: 0.8537
# Epoch 46/50
# 2/2 [==============================] - 3s 544ms/step - loss: 2.3784 - accuracy: 0.9268
# Epoch 47/50
# 2/2 [==============================] - 3s 588ms/step - loss: 1.6044 - accuracy: 0.9268
# Epoch 48/50
# 2/2 [==============================] - 3s 539ms/step - loss: 0.8655 - accuracy: 0.8780
# Epoch 49/50
# 2/2 [==============================] - 3s 538ms/step - loss: 1.2361 - accuracy: 0.9024
# Epoch 50/50
# 2/2 [==============================] - 3s 553ms/step - loss: 0.4931 - accuracy: 0.9268
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0810 - accuracy: 1.0000
# 1.0
# Epoch 1/50
# 2/2 [==============================] - 4s 615ms/step - loss: 171.2773 - accuracy: 0.3415
# Epoch 2/50
# 2/2 [==============================] - 3s 570ms/step - loss: 352.5221 - accuracy: 0.4146
# Epoch 3/50
# 2/2 [==============================] - 3s 565ms/step - loss: 681.4816 - accuracy: 0.3415
# Epoch 4/50
# 2/2 [==============================] - 3s 560ms/step - loss: 256.2700 - accuracy: 0.6098
# Epoch 5/50
# 2/2 [==============================] - 3s 557ms/step - loss: 239.1704 - accuracy: 0.5854
# Epoch 6/50
# 2/2 [==============================] - 3s 564ms/step - loss: 183.7508 - accuracy: 0.5122
# Epoch 7/50
# 2/2 [==============================] - 3s 550ms/step - loss: 125.7879 - accuracy: 0.5610
# Epoch 8/50
# 2/2 [==============================] - 3s 558ms/step - loss: 87.8853 - accuracy: 0.5610
# Epoch 9/50
# 2/2 [==============================] - 3s 561ms/step - loss: 64.0921 - accuracy: 0.6341
# Epoch 10/50
# 2/2 [==============================] - 3s 561ms/step - loss: 58.7092 - accuracy: 0.5610
# Epoch 11/50
# 2/2 [==============================] - 3s 571ms/step - loss: 35.0603 - accuracy: 0.7317
# Epoch 12/50
# 2/2 [==============================] - 3s 561ms/step - loss: 46.2477 - accuracy: 0.6098
# Epoch 13/50
# 2/2 [==============================] - 3s 564ms/step - loss: 36.6485 - accuracy: 0.5854
# Epoch 14/50
# 2/2 [==============================] - 3s 565ms/step - loss: 35.4700 - accuracy: 0.5854
# Epoch 15/50
# 2/2 [==============================] - 3s 547ms/step - loss: 18.5765 - accuracy: 0.6585
# Epoch 16/50
# 2/2 [==============================] - 3s 545ms/step - loss: 20.5383 - accuracy: 0.7073
# Epoch 17/50
# 2/2 [==============================] - 3s 564ms/step - loss: 14.4276 - accuracy: 0.6829
# Epoch 18/50
# 2/2 [==============================] - 3s 539ms/step - loss: 15.7442 - accuracy: 0.6585
# Epoch 19/50
# 2/2 [==============================] - 3s 558ms/step - loss: 11.4039 - accuracy: 0.7561
# Epoch 20/50
# 2/2 [==============================] - 3s 554ms/step - loss: 11.3765 - accuracy: 0.7317
# Epoch 21/50
# 2/2 [==============================] - 3s 570ms/step - loss: 4.9694 - accuracy: 0.7805
# Epoch 22/50
# 2/2 [==============================] - 3s 584ms/step - loss: 2.7897 - accuracy: 0.8293
# Epoch 23/50
# 2/2 [==============================] - 3s 608ms/step - loss: 2.9640 - accuracy: 0.8293
# Epoch 24/50
# 2/2 [==============================] - 3s 588ms/step - loss: 5.5278 - accuracy: 0.7317
# Epoch 25/50
# 2/2 [==============================] - 3s 576ms/step - loss: 3.2457 - accuracy: 0.7805
# Epoch 26/50
# 2/2 [==============================] - 3s 588ms/step - loss: 0.9070 - accuracy: 0.8293
# Epoch 27/50
# 2/2 [==============================] - 3s 579ms/step - loss: 4.3809 - accuracy: 0.7317
# Epoch 28/50
# 2/2 [==============================] - 3s 591ms/step - loss: 2.2742 - accuracy: 0.8049
# Epoch 29/50
# 2/2 [==============================] - 3s 548ms/step - loss: 4.4303 - accuracy: 0.7805
# Epoch 30/50
# 2/2 [==============================] - 3s 564ms/step - loss: 3.3379 - accuracy: 0.8049
# Epoch 31/50
# 2/2 [==============================] - 3s 563ms/step - loss: 1.9249 - accuracy: 0.8049
# Epoch 32/50
# 2/2 [==============================] - 3s 544ms/step - loss: 1.8421 - accuracy: 0.8049
# Epoch 33/50
# 2/2 [==============================] - 3s 565ms/step - loss: 0.5404 - accuracy: 0.8780
# Epoch 34/50
# 2/2 [==============================] - 3s 563ms/step - loss: 1.9562 - accuracy: 0.8049
# Epoch 35/50
# 2/2 [==============================] - 3s 583ms/step - loss: 3.4800 - accuracy: 0.7805
# Epoch 36/50
# 2/2 [==============================] - 3s 563ms/step - loss: 3.0317 - accuracy: 0.6829
# Epoch 37/50
# 2/2 [==============================] - 3s 570ms/step - loss: 0.6407 - accuracy: 0.9024
# Epoch 38/50
# 2/2 [==============================] - 3s 566ms/step - loss: 1.5906 - accuracy: 0.7317
# Epoch 39/50
# 2/2 [==============================] - 3s 555ms/step - loss: 4.2327 - accuracy: 0.7317
# Epoch 40/50
# 2/2 [==============================] - 3s 546ms/step - loss: 7.3209 - accuracy: 0.7073
# Epoch 41/50
# 2/2 [==============================] - 3s 566ms/step - loss: 2.7950 - accuracy: 0.7805
# Epoch 42/50
# 2/2 [==============================] - 3s 553ms/step - loss: 2.8149 - accuracy: 0.8293
# Epoch 43/50
# 2/2 [==============================] - 3s 539ms/step - loss: 3.6094 - accuracy: 0.7805
# Epoch 44/50
# 2/2 [==============================] - 3s 553ms/step - loss: 1.0828 - accuracy: 0.8293
# Epoch 45/50
# 2/2 [==============================] - 3s 550ms/step - loss: 0.3991 - accuracy: 0.8537
# Epoch 46/50
# 2/2 [==============================] - 3s 541ms/step - loss: 1.1478 - accuracy: 0.8049
# Epoch 47/50
# 2/2 [==============================] - 3s 552ms/step - loss: 1.2921 - accuracy: 0.8049
# Epoch 48/50
# 2/2 [==============================] - 3s 552ms/step - loss: 0.1815 - accuracy: 0.9024
# Epoch 49/50
# 2/2 [==============================] - 3s 548ms/step - loss: 0.6951 - accuracy: 0.8537
# Epoch 50/50
# 2/2 [==============================] - 3s 640ms/step - loss: 0.3209 - accuracy: 0.9024
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1927 - accuracy: 1.0000
# 1.0
# Epoch 1/50
# 2/2 [==============================] - 4s 575ms/step - loss: 401.3557 - accuracy: 0.2439
# Epoch 2/50
# 2/2 [==============================] - 3s 595ms/step - loss: 410.5094 - accuracy: 0.4146
# Epoch 3/50
# 2/2 [==============================] - 3s 557ms/step - loss: 518.1824 - accuracy: 0.4390
# Epoch 4/50
# 2/2 [==============================] - 3s 571ms/step - loss: 308.3405 - accuracy: 0.6829
# Epoch 5/50
# 2/2 [==============================] - 3s 555ms/step - loss: 180.8248 - accuracy: 0.7073
# Epoch 6/50
# 2/2 [==============================] - 3s 548ms/step - loss: 149.0160 - accuracy: 0.7073
# Epoch 7/50
# 2/2 [==============================] - 3s 550ms/step - loss: 174.8436 - accuracy: 0.6098
# Epoch 8/50
# 2/2 [==============================] - 3s 550ms/step - loss: 152.8194 - accuracy: 0.7805
# Epoch 9/50
# 2/2 [==============================] - 3s 652ms/step - loss: 96.9372 - accuracy: 0.7805
# Epoch 10/50
# 2/2 [==============================] - 3s 560ms/step - loss: 121.0829 - accuracy: 0.7805
# Epoch 11/50
# 2/2 [==============================] - 3s 605ms/step - loss: 128.1603 - accuracy: 0.6829
# Epoch 12/50
# 2/2 [==============================] - 3s 560ms/step - loss: 129.5258 - accuracy: 0.7561
# Epoch 13/50
# 2/2 [==============================] - 3s 602ms/step - loss: 102.1838 - accuracy: 0.7805
# Epoch 14/50
# 2/2 [==============================] - 3s 553ms/step - loss: 45.3974 - accuracy: 0.8537
# Epoch 15/50
# 2/2 [==============================] - 3s 612ms/step - loss: 23.3218 - accuracy: 0.9024
# Epoch 16/50
# 2/2 [==============================] - 3s 605ms/step - loss: 15.9356 - accuracy: 0.9024
# Epoch 17/50
# 2/2 [==============================] - 3s 611ms/step - loss: 31.9553 - accuracy: 0.9024
# Epoch 18/50
# 2/2 [==============================] - 3s 549ms/step - loss: 53.0324 - accuracy: 0.8049
# Epoch 19/50
# 2/2 [==============================] - 3s 599ms/step - loss: 34.9395 - accuracy: 0.8780
# Epoch 20/50
# 2/2 [==============================] - 3s 578ms/step - loss: 22.6806 - accuracy: 0.8780
# Epoch 21/50
# 2/2 [==============================] - 3s 589ms/step - loss: 26.7900 - accuracy: 0.8049
# Epoch 22/50
# 2/2 [==============================] - 3s 582ms/step - loss: 9.7607 - accuracy: 0.8780
# Epoch 23/50
# 2/2 [==============================] - 3s 599ms/step - loss: 30.5463 - accuracy: 0.8537
# Epoch 24/50
# 2/2 [==============================] - 3s 557ms/step - loss: 18.1959 - accuracy: 0.7317
# Epoch 25/50
# 2/2 [==============================] - 3s 544ms/step - loss: 10.2660 - accuracy: 0.8537
# Epoch 26/50
# 2/2 [==============================] - 3s 536ms/step - loss: 8.6876 - accuracy: 0.8537
# Epoch 27/50
# 2/2 [==============================] - 3s 547ms/step - loss: 24.9842 - accuracy: 0.9024
# Epoch 28/50
# 2/2 [==============================] - 3s 558ms/step - loss: 14.7965 - accuracy: 0.9024
# Epoch 29/50
# 2/2 [==============================] - 3s 609ms/step - loss: 21.0910 - accuracy: 0.8537
# Epoch 30/50
# 2/2 [==============================] - 3s 579ms/step - loss: 12.4787 - accuracy: 0.8537
# Epoch 31/50
# 2/2 [==============================] - 3s 555ms/step - loss: 17.9776 - accuracy: 0.8537
# Epoch 32/50
# 2/2 [==============================] - 3s 553ms/step - loss: 19.9424 - accuracy: 0.9024
# Epoch 33/50
# 2/2 [==============================] - 3s 549ms/step - loss: 14.5583 - accuracy: 0.8049
# Epoch 34/50
# 2/2 [==============================] - 3s 588ms/step - loss: 3.6566 - accuracy: 0.9024
# Epoch 35/50
# 2/2 [==============================] - 3s 570ms/step - loss: 25.3072 - accuracy: 0.8537
# Epoch 36/50
# 2/2 [==============================] - 3s 568ms/step - loss: 0.0551 - accuracy: 0.9512
# Epoch 37/50
# 2/2 [==============================] - 3s 554ms/step - loss: 28.0880 - accuracy: 0.8537
# Epoch 38/50
# 2/2 [==============================] - 3s 591ms/step - loss: 0.2291 - accuracy: 0.9512
# Epoch 39/50
# 2/2 [==============================] - 3s 585ms/step - loss: 4.9608 - accuracy: 0.8293
# Epoch 40/50
# 2/2 [==============================] - 3s 567ms/step - loss: 5.6492 - accuracy: 0.9024
# Epoch 41/50
# 2/2 [==============================] - 3s 552ms/step - loss: 3.4736 - accuracy: 0.8780
# Epoch 42/50
# 2/2 [==============================] - 3s 559ms/step - loss: 9.6751 - accuracy: 0.9024
# Epoch 43/50
# 2/2 [==============================] - 3s 601ms/step - loss: 46.6451 - accuracy: 0.9024
# Epoch 44/50
# 2/2 [==============================] - 3s 570ms/step - loss: 14.7529 - accuracy: 0.8780
# Epoch 45/50
# 2/2 [==============================] - 3s 560ms/step - loss: 7.3262 - accuracy: 0.9512
# Epoch 46/50
# 2/2 [==============================] - 3s 575ms/step - loss: 10.3714 - accuracy: 0.9268
# Epoch 47/50
# 2/2 [==============================] - 3s 548ms/step - loss: 8.4690 - accuracy: 0.9512
# Epoch 48/50
# 2/2 [==============================] - 3s 567ms/step - loss: 5.2372 - accuracy: 0.9268
# Epoch 49/50
# 2/2 [==============================] - 3s 561ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 3s 547ms/step - loss: 12.7820 - accuracy: 0.8780
# 1/1 [==============================] - 0s 280ms/step - loss: 4.9845 - accuracy: 0.8000
# 0.800000011920929
# 0.9018181920051574
